# %%
import instatools
import json

# %%
# this takes the account with given username, grabs all posts and dumps to a local json file with name based on that username

username = 'drought_season'

my_user = instatools.Instauser()
my_user.get_user_from_web(username)

all_data_list_tagged = my_user.get_all_data_list_tagged(username)
print(all_data_list_tagged)
# Out:
# [{'id': '3245249240971187115', 'shortcode': 'C0JcP2XsZOr', 'width': 1080, 'height': 1320, 'display_url': 'https://scontent-iad3-1.cdninstagram.com/v/t39.30808-6/406397027_18324375601100113_3051415442164867838_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=101&_nc_ohc=TSvGN1eVloEAX91SwQT&edm=ALdeuSgAAAAA&ccb=7-5&oh=00_AfCrIhDW97TsH8b1BE942iZJbh9qEVJ-2TmMyt2W9V-NjA&oe=656D0467&_nc_sid=9fa07d', 'tagged_user_list': [], 'fact_check_overall_rating': '', 'fact_check_information': '', 'gating_info': '', 'sharing_friction_info': '', 'media_overlay_info': '', 'media_preview': '', 'userid': '3053428112', 'username': 'babysonfirecafe', 'is_video': False, 'has_upcoming_event': False, 'accessibility_caption': "Photo shared by BABY'S ON FIRE on November 27, 2023 tagging @drought_season. May be an image of 1 person, candle holder, lighting, lamp, lamp shade, chandelier and foundry.", 'caption': {'node': {'text': 'Please join us in wishing Sean a fond farewell this week, his last day is Wednesday. 😘Sean will be leaving Baltimore for the next chapter in his life, focusing on his writing . If you haven’t checked out his podcast, Burning Glass, we suggest you do. \n\nSean started working for us in early 2018 after co-owner David started chatting with him & who he thought was his partner one afternoon in the shop. The three exchanged jokes and funny stories as they drank their coffee drinks. Little did David know that they were actually on a first date, lol. \n\nSean returned to the shop a couple days later to do some writing. David struck up another conversation with him and asked where his partner was when Sean informed him that it was actually a date and it didn’t work out, but that they became good friends. David then proceeded to find out that Sean had worked in coffee since he was 16. He asked what would it take for him to leave his current job and come work at Baby’s. Sean simply replied, “not much” and the rest is history.\n\nFor the past 5 years, Sean has been one of our hardest workers always looking to make the shop the best it could be. There have been so many laughs and deep conversations with both co-workers and customers alike over the years. \n\nAll of us at Baby’s will miss Sean dearly and thank him for his dedication to the shop and the community that he helped fuel on a daily basis. Best of luck Sean on your next chapter. Much love. \n\n#simplythebest #coffeefamily  #baltimoresbest #burningglasspodcast #wewillmissyou @drought_season'}}, 'number_of_comments': 4, 'comments_disabled': False, 'timestamp': 1701083878, 'number_of_likes': 107, 'location': '', 'sidecar_to_children_list': []}, {'id': '3245248084584749387', 'shortcode': 'C0Jb_BZsNlL', 'width': 1080, 'height': 1238, 'display_url': 'https://scontent-iad3-1.cdninstagram.com/v/t39.30808-6/406435672_18324374857100113_4987140121806521771_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=101&_nc_ohc=lhsk4bhlutgAX9RC8zL&edm=ALdeuSgAAAAA&ccb=7-5&oh=00_AfBguHkJkKRfEVFVEO-a_xC49ITEiIVwQiYi3FWJHzuCQg&oe=656D2728&_nc_sid=9fa07d', 'tagged_user_list': [], 'fact_check_overall_rating': '', 'fact_check_information': '', 'gating_info': '', 'sharing_friction_info': '', 'media_overlay_info': '', 'media_preview': '', 'userid': '3053428112', 'username': 'babysonfirecafe', 'is_video': False, 'has_upcoming_event': False, 'accessibility_caption': "Photo shared by BABY'S ON FIRE on November 27, 2023 tagging @drought_season. May be an image of 1 person, beard, polaroid and coffee cup.", 'caption': {'node': {'text': 'Please join us in wishing Sean a fond farewell this week, his last day is Wednesday. 😘 Sean will be leaving Baltimore for the next chapter in his life, focusing on his writing . If you haven’t checked out his podcast, Burning Glass, we suggest you do. \n\nSean started working for us in early 2018 after co-owner David started chatting with him & who he thought was his partner one afternoon in the shop. The thre ...

# %%
# this data is available here for further exploration if desired, e.g. below lists all display urls for all posts

for entry in all_data_list_tagged:
  print('do something!')
# Out:
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
# do something!
